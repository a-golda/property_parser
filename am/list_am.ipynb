# %%
import tqdm
import requests
from bs4 import BeautifulSoup

# %%
class ScraperListam:
    """
    Gett all links and all content from https://www.list.am/category/56. 
    """
    headers = {
    'User-Agent': 'My User Agent 1.0',
    'From': 'golubev.anton94@mail.ru'  # This is another valid field
    }
    
    def __init__(self):
        pass
        
    def scrap(self):
        links = {}
        city_links = []
        page = 1
        while True:
            print(page)
            global url
            url = self.get_one_link(page)
            res = requests.get(url, headers=headers)
            soup = BeautifulSoup(res.content)
            global a
            a = check_last_page(soup, url)
            if a:
                tmp_links = self.get_links_from_page(soup)
            else:
                break
            for link in tmp_links:
                city_links.append(link)
            page+=1
        links = city_links
        return links
                
                
    def get_one_link(self, page):
        url = f'https://www.list.am/category/56/{page}?n=1'
        return url
    
    def get_links_from_page(self, soup):
        res_links = [i.get("href") for i in soup.findAll("a", href=True)]
        res_links = [i for i in links if 'item' in i]
        return res_links
    
    def check_last_page(soup, link):
        href_url = soup.find('link').get('href')
        print(href_url)
        if href_url in link:
            return True
        else:
            return False

# %%
scraper = ScraperListam()
general_links = scraper.scrap()
# Out:
# 1

# %%
url
# Out:
# 'https://www.list.am/category/56/1?n=1'

# %%
href_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-95f928cb2d22> in <module>
# ----> 1 href_url
#
# NameError: name 'href_url' is not defined

# %%
headers = {
    'User-Agent': 'My User Agent 1.0',
    'From': 'golubev.anton94@mail.ru'  # This is another valid field
}

r = requests.get(f"https://www.list.am/ru/category/56/{12}?n=1",
                headers=headers)

# %%
soup = BeautifulSoup(r.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru"><head><link href="/ru/category/56/13?n=1" rel="next"/><link href="/ru/category/56/11?n=1" rel="prev"/><meta content="app-id=1219826928" name="apple-itunes-app"/><link href="/manifest.json" rel="manifest"/><meta content="50,256 объявлений. Аренда квартир: здесь вы легко и недорого сможете снять или сдать квартиру в Армении и Ереване." name="description"/><link href="https://www.list.am/ru/category/56/12?n=1" rel="canonical"/><link href="https://www.list.am/category/56/12?n=1" hreflang="hy" rel="alternate"/><link href="https://www.list.am/ru/category/56/12?n=1" hreflang="ru" rel="alternate"/><link href="https://www.list.am/en/category/56/12?n=1" hreflang="en" rel="alternate"/><meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/><meta content="yes" name="apple-mobile-web-app-capable"/><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create','UA-1637671-15','auto');ga('send','pageview');</script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-KVLP4BC4K8"></script><script>window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments);}gtag('js',new Date());gtag('config','G-KVLP4BC4K8');</script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>Аренда квартир. Аренда квартир квартир в Ереване и Армении от хозяев и агентств, посуточно и долгосрочно. Страница 12 - List.am</title><link href="/l-h20.css" rel="stylesheet" type="text/css"/><link href="/m-e89.css" media="screen and (max-device-width:980px),screen and (max-device-width:1024px) and (orientation:portrait)" rel="stylesheet" type="text/css"/></head><body><div id="mainoverlay"></div><div id="ph"><script>;</script><div class="c"><a class="bhm" href="/ru/"></a><a class="nomo" href="/ru/" id="l"></a><div id="menu"><span><label class="menu-button-container"><div class="menu-button"></div></label>Разделы</span><div></div></div><div id="search"><form action="/category" id="idSearchF" method="GET" name="s"><input id="idSearchBox" maxlength="32" name="q" onkeydown="return fsubmit(event)" placeholder="Поиск" type="text" value=""/><a href="#"></a><button aria-label="Поиск" onclick="if(!$('#idSearchBox').val())$('#idSearchBox').focus();else document.s.submit()" tabindex="-1" type="button"></button></form></div><div class="inx"><div></div></div><div class="b"><a class="out" href="/my" id="ma">Личный кабинет</a><a href="/add" id="ap">Разместить объявление</a></div></div></div><div id="main"><div id="sstar"><div class="off" onclick="dlgo('В избранное','/?w=40&amp;next=%2Fru%2Fcategory%2F56%2F12%3Fn%3D1',500);return false;" title="В избранное"></div></div><div id="crumb"><ol itemscope="" itemtype="https://schema.org/BreadcrumbList"><li><a href="/ru/"><span>Главная</span></a></li><li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem"><a href="/category/54" itemprop="item"><span itemprop="name">Недвижимость</span><meta content="1" itemprop="position"/></a></li><li><div><span>Долгосрочная аренда</span></div></li><li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem"><a href="/category/56" itemprop="item"><span itemprop="name">Квартиры</span><meta content="2" itemprop="position"/></a></li></ol></div><div class="share"><div class="c"><a href="#" onclick="ga('send','event','share','facebook');return dlgw('https://www.facebook.com/share.php?u=https://www.list.am/ru/category/56/12?n=1',560,430);" target="share" title="Facebook"></a><a href="#" onclick="ga('send','event','share','vkontakte');return dlgw('https://vkontakte.ru/share.php?url=https://www.list.am/ru/category/56/12?n=1',560,430);" target="share" title="В Контакте"></a><a href="#" onclick="ga('sen ...

# %%
links = [i.get("href") for i in soup.findAll("a", href=True)]
links = [i for i in links if 'item' in i]

# %%
soup.find('link').get('href')
# Out:
# '/ru/category/56/13?n=1'

# %%
def check_last_page(soup, link):
    if soup.find('link').get('href') in link:
        return True
    else:
        return False

# %%
soup.find('link').get('href')
# Out:
# '/ru/category/56/13?n=1'
